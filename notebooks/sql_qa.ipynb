# %%
import json
import numpy as np
import pandas as pd
from sqlalchemy import create_engine

from langchain_openai import ChatOpenAI
from langchain_community.agent_toolkits import create_sql_agent
from langchain_community.utilities import SQLDatabase

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 1000)

# %% [markdown]
# ## Import data
#
# This data set is the same data that was used by Paco Nathan in his [blog post](https://neo4j.com/developer-blog/entity-resolved-knowledge-graphs/) on entity-resolved knowledge graphs.  It is a combination of 3 files:
#
# 1. SafeGraph: a dataset of places of interest such as businesses and organizations
# 2. US Department of Labor Wage and Hour Compliance Action Data (DOL_WHISARD): a publicly-available dataset of labor violations of various companies
# 3. US Small Business Administration PPP Loans over $150K (PPP_LOANS): a publicly-available data set of Paycheck Protection Program (PPP) was a federal loans awarded to help small businesses keep their employees during the COVID-19 pandemic
#
# These files are available for download [here](https://senzing.com/get-erkg-tutorial-evaluation-data/).

# %%
sg_data = []

with open('./SafeGraph_LasVegas_Partial.json') as f:
    for line in f:
        sg_data.append(json.loads(line))

sg_df = pd.DataFrame(sg_data)

dol_data = []

with open('./Dept_Labor_Whisard_LasVegas.json') as f:
    for line in f:
        dol_data.append(json.loads(line))

dol_df = pd.DataFrame(dol_data)
dol_df = dol_df.iloc[:, :13]  # Each individual infraction count is shown beyond column 13

ppp_data = []

with open('./PPP_Loans_Over_150k_LasVegas.json') as f:
    for line in f:
        ppp_data.append(json.loads(line))

ppp_df = pd.DataFrame(ppp_data)

dol_df.replace('null', np.nan, inplace=True)

sg_df.shape, dol_df.shape, ppp_df.shape
# Out:
# ((79946, 25), (1554, 13), (3488, 19))

# %% [markdown]
# ## Querying tabular data
#
# I had originally tried to use the Pandas agent from LangChain but did not have much luck with it.  So I therefore elected to stand up a quickie little SQLite database.  My brief experiment here led me to conclude that the SQL agent for LangChain was a bit more reliable.

# %%
engine = create_engine("sqlite:///erkg_demo.db")
sg_df.to_sql("sg", engine, index=False)
ppp_df.to_sql("ppp", engine, index=False)
dol_df.to_sql("dol", engine, index=False)

# %% [markdown]
# ### Verifying the SQL connection with LangChain...

# %%
db = SQLDatabase(engine=engine)

print(db.dialect)
print(db.get_usable_table_names())
print(db.run("SELECT count(*) FROM sg;"))
print(db.run("SELECT count(*) FROM ppp;"))
print(db.run("SELECT count(*) FROM dol;"))
# Out:
# sqlite
# ['dol', 'ppp', 'sg']
# [(79946,)]
# [(3488,)]
# [(1554,)]

# %%
sql_agent_executor = create_sql_agent(
    ChatOpenAI(temperature=0, model="gpt-4o-2024-05-13"), 
    db=db, 
    agent_type="openai-tools", 
    verbose=True
)

# %% [markdown]
# ## Let's get to work asking some questions!
#
# First, let's just see that the SQL agent can handle some basic data ops questions.

# %%
sql_agent_executor.invoke('what tables are present?')
# Out:
# > Entering new SQL Agent Executor chain...
#
# Invoking: `sql_db_list_tables` with `{}`
#
#
# dol, ppp, sgThe database contains the following tables:
# 1. dol
# 2. ppp
# 3. sg
#
# If you have any specific questions about these tables or need information from them, please let me know!
#
# > Finished chain.
# {'input': 'what tables are present?',
#  'output': 'The database contains the following tables:\n1. dol\n2. ppp\n3. sg\n\nIf you have any specific questions about these tables or need information from them, please let me know!'}

# %%
sql_agent_executor.invoke('tell me about the tables in the database')
# Out:
# > Entering new SQL Agent Executor chain...
#
# Invoking: `sql_db_list_tables` with `{}`
#
#
# dol, ppp, sg
# Invoking: `sql_db_schema` with `{'table_names': 'dol, ppp, sg'}`
#
#
#
# CREATE TABLE dol (
# 	"RECORD_TYPE" TEXT,
# 	"DATA_SOURCE" TEXT,
# 	"RECORD_ID" BIGINT,
# 	case_id BIGINT,
# 	"BUSINESS_NAME_ORG" TEXT,
# 	"LEGAL_NAME_ORG" TEXT,
# 	"BUSINESS_ADDR_LINE1" TEXT,
# 	"BUSINESS_ADDR_CITY" TEXT,
# 	"BUSINESS_ADDR_STATE" TEXT,
# 	"BUSINESS_ADDR_POSTAL_CODE" TEXT,
# 	naic_cd TEXT,
# 	naics_code_description TEXT,
# 	case_violtn_cnt BIGINT
# )
#
# /*
# 3 rows from dol table:
# RECORD_TYPE	DATA_SOURCE	RECORD_ID	case_id	BUSINESS_NAME_ORG	LEGAL_NAME_ORG	BUSINESS_ADDR_LINE1	BUSINESS_ADDR_CITY	BUSINESS_ADDR_STATE	BUSINESS_ADDR_POSTAL_CODE	naic_cd	naics_code_description	case_violtn_cnt
# ORGANIZATION	DoL_WHISARD	53	1658108	Fabulous Freddy's (Trailwood)	Fabulous LLC	9611 Trail Wood Drive	Las Vegas	NV	89134	811192	Car Washes	0
# ORGANIZATION	DoL_WHISARD	165	1419689	Boulder Station Hotel & Casino	Boulder Station, Inc.	4111 Boulder Hwy	Las Vegas	NV	89121	721120	Casino Hotels	1
# ORGANIZATION	DoL_WHISARD	178	1424856	MSI Landscaping	MIST Systems International, Inc.	4820 Quality Court, #B	Las Vegas	NV	89103	561730	Landscaping Services	14
# */
#
#
# CREATE TABLE ppp (
# 	"RECORD_TYPE" TEXT,
# 	"DATA_SOURCE" TEXT,
# 	"RECORD_ID" BIGINT,
# 	"Loan_Range" TEXT,
# 	"BUSINESS_NAME_ORG" TEXT,
# 	"BUSINESS_ADDR_LINE1" TEXT,
# 	"BUSINESS_ADDR_CITY" TEXT,
# 	"BUSINESS_ADDR_STATE" TEXT,
# 	"BUSINESS_ADDR_POSTAL_CODE" TEXT,
# 	"NAICS_Code" TEXT,
# 	"Business_Type" TEXT,
# 	"OwnedByRaceEthnicity" TEXT,
# 	"OwnedBy" TEXT,
# 	"OwnedByVeteran" TEXT,
# 	"NonProfit" TEXT,
# 	"JobsReported" TEXT,
# 	"DateApproved" TEXT,
# 	"Lender" TEXT,
# 	"CD" TEXT
# )
#
# /*
# 3 rows from ppp table:
# RECORD_TYPE	DATA_SOURCE	RECORD_ID	Loan_Range	BUSINESS_NAME_ORG	BUSINESS_ADDR_LINE1	BUSINESS_ADDR_CITY	BUSINESS_ADDR_STATE	BUSINESS_ADDR_POSTAL_CODE	NAICS_Code	Business_Type	OwnedByRaceEthnicity	OwnedBy	OwnedByVeteran	NonProfit	JobsReported	DateApproved	Lender	CD
# ORGANIZATION	PPP_LOANS	7017	c $1-2 million	INFINITY HOSPICE CARE OF LAS VEGAS, LLC	5110 N 40TH ST STE 107	PHOENIX	AZ	85018	623110	Limited  Liability Company(LLC)	Unanswered	Male Owned	Unanswered		137	05/01/2020	JPMorgan Chase Bank, National Association	AZ-09
# ORGANIZATION	PPP_LOANS	7018	d $350,000-1 million	CLUB TATTOO LAS VEGAS LLC	1839 s. almaschool rd. ste 230	MESA	AZ	85210	812199	Limited  Liability Company(LLC)	Unanswered	Male Owned	Non-Veteran		15	05/01/2020	JPMorgan Chase Bank, National Association	AZ-09
# ORGANIZATION	PPP_LOANS	7021	d $350,000-1 million	LAS VEGAS LABOR, LLC	10265 W Camelback Rd, Ste 104	PHOENIX	AZ	85037	111421	Limited  Liability Company(LLC)	Unanswered	Unanswered	Unanswered		0	04/07/2020	UMB Bank, National Association	AZ-03
# */
#
#
# CREATE TABLE sg (
# 	"DATA_SOURCE" TEXT,
# 	"RECORD_ID" TEXT,
# 	"RECORD_TYPE" TEXT,
# 	"PLACEKEY" TEXT,
# 	"REL_ANCHOR_DOMAIN" TEXT,
# 	"REL_ANCHOR_KEY" TEXT,
# 	"LOCATION_NAME_ORG" TEXT,
# 	"BRANDS" TEXT,
# 	"TOP_CATEGORY" TEXT,
# 	"SUB_CATEGORY" TEXT,
# 	"NAICS_CODE" TEXT,
# 	"BUSINESS_GEO_LATITUDE" TEXT,
# 	"BUSINESS_GEO_LONGITUDE" TEXT,
# 	"CATEGORY_TAGS" TEXT,
# 	"CLOSED_ON" TEXT,
# 	"TRACKING_CLOSED_SINCE" TEXT,
# 	"PHONE_NUMBER" TEXT,
# 	"BUSINESS_ADDR_COUNTRY" TEXT,
# 	"BUSINESS_ADDR_FULL" TEXT,
# 	"MAILING_VERIFIED_STATUS" TEXT,
# 	"REL_POINTER_DOMAIN" TEXT,
# 	"REL_POINTER_KEY" TEXT,
# 	"REL_POINTER_ROLE" TEXT,
# 	"OPENED_ON" TEXT,
# 	"IS_INTERSECTION" TEXT
# )
#
# /*
# 3 rows from sg table:
# DATA_SOURCE	RECORD_ID	RECORD_TYPE	PLACEKEY	REL_ANCHOR_DOMAIN	REL_ANCHOR_KEY	LOCATION_NAME_ORG	BRANDS	TOP_CATEGORY	SUB_CATEGORY	NAICS_CODE	BUSINESS_GEO_LATITUDE	BUSINESS_GEO_LONGITUDE	CATEGORY_TAGS	CLOSED_ON	TRACKING_CLOSED_SINCE	PHONE_NUMBER	BUSINESS_ADDR_COUNTRY	BUSINESS_ADDR_FULL	MAILING_VERIFIED_STATUS	REL_POINTER_DOMAIN	REL_POINTER_KEY	REL_POINTER_ROLE	OPENED_ON	IS_INTERSECTION
# SAFEGRAPH	225-222@5yv-j92-tn5	ORGANIZATION	225-222@5yv-j92-tn5	PLACEKEY	225-222@5yv-j92-tn5	Cantwell Michelle L Atty	[]	Legal Services	Offices of Lawyers	541110	36.145647	-115.186399	[]	2024-02-01	2019-07-01	+17023627800	US	3320 W Sahara Ave Las Vegas NV 89102-3223	VERIFIED_PREMISE	None	None	None	None	None
# SAFEGRAPH	226-222@5yv-hmm-whq	ORGANIZATION	226-222@5yv-hmm-whq	PLACEKEY	226-222@5yv-hmm-whq	Pieology Pizzeria	[ { "safegraph_brand_id": "SG_BRAND_f372f9969f6e1ae119a13ff4fc78fd2d", "safegraph_brand_name": "Pieo	Restaurants and Other Eating Places	Limited-Service Restaurants	722513	36.144906	-115.332644	[ "Counter Service", "Dinner", "Fast Food", "Lunch", "Pizza" ]	None	2019-07-01	+17023314454	US	10965 Lavender Hill Dr Ste 130 Las Vegas NV 89135-2951	VERIFIED_DELIVERY_POINT	PLACEKEY	zzw-223@5yv-hkm-rc5	PARENT	None	None
# SAFEGRAPH	22s-222@5yv-jbz-jgk	ORGANIZATION	22s-222@5yv-jbz-jgk	PLACEKEY	22s-222@5yv-jbz-jgk	Ellen Peneyra	[]	Offices of Other Health Practitioners	Offices of All Other Miscellaneous Health Practitioners	621399	36.10289	-115.121807	[]	None	2019-07-01	+17027397716	US	2275 Renaissance Dr Ste D Las Vegas NV 89119-6797	VERIFIED_DELIVERY_POINT	PLACEKEY	22g-222@5yv-jbz-h89	PARENT	None	None
# */The database contains the following tables:
#
# 1. **dol**: This table appears to contain information about organizations, including their business names, addresses, NAICS codes, and violation counts.
#    - Example columns: `RECORD_TYPE`, `DATA_SOURCE`, `RECORD_ID`, `BUSINESS_NAME_ORG`, `BUSINESS_ADDR_CITY`, `BUSINESS_ADDR_STATE`, `naics_code_description`, `case_violtn_cnt`.
#
# 2. **ppp**: This table seems to store data related to PPP loans, including loan ranges, business names, addresses, NAICS codes, business types, and other related information.
#    - Example columns: `RECORD_TYPE`, `DATA_SOURCE`, `RECORD_ID`, `Loan_Range`, `BUSINESS_NAME_ORG`, `BUSINESS_ADDR_CITY`, `BUSINESS_ADDR_STATE`, `NAICS_Code`, `Business_Type`, `JobsReported`, `DateApproved`, `Lender`.
#
# 3. **sg**: This table contains information about various locations, including their names, brands, categories, NAICS codes, geographical coordinates, and other related details.
#    - Example columns: `DATA_SOURCE`, `RECORD_ID`, `RECORD_TYPE`, `PLACEKEY`, `LOCATION_NAME_ORG`, `BRANDS`, `TOP_CATEGORY`, `SUB_CATEGORY`, `NAICS_CODE`, `BUSINESS_GEO_LATITUDE`, `BUSINESS_GEO_LONGITUDE`, `PHONE_NUMBER`, `BUSINESS_ADDR_FULL`.
#
# If you have any specific questions or need information from any of these tables, please let me know!
#
# > Finished chain.
# {'input': 'tell me about the tables in the database',
#  'output': 'The database contains the following tables:\n\n1. **dol**: This table appears to contain information about organizations, including their business names, addresses, NAICS codes, and violation counts.\n   - Example columns: `RECORD_TYPE`, `DATA_SOURCE`, `RECORD_ID`, `BUSINESS_NAME_ORG`, `BUSINESS_ADDR_CITY`, `BUSINESS_ADDR_STATE`, `naics_code_description`, `case_violtn_cnt`.\n\n2. **ppp**: This table seems to store data related to PPP loans, including loan ranges, business names, addresses, NAICS codes, business types, and other related information.\n   - Example columns: `RECORD_TYPE`, `DATA_SOURCE`, `RECORD_ID`, `Loan_Range`, `BUSINESS_NAME_ORG`, `BUSINESS_ADDR_CITY`, `BUSINESS_ADDR_STATE`, `NAICS_Code`, `Business_Type`, `JobsReported`, `DateApproved`, `Lender`.\n\n3. **sg**: This table contains information about various locations, including their names, brands, categories, NAICS codes, geographical coordinates, and other related details.\n   - Example columns: `DATA_SOURCE`, `RECORD_ID`, `RECORD_TYPE`, `PLACEKEY`, `LOCATION_NAME_ORG`, `BRANDS`, `TOP_CATEGORY`, `SUB_CATEGORY`, `NAICS_CODE`, `BUSINESS_GEO_LATITUDE`, `BUSINESS_GEO_LONGITUDE`, `PHONE_NUMBER`, `BUSINESS_ADDR_FULL`.\n\nIf you have any specific questions or need information from any of these tables, please let me know!'}

# %% [markdown]
# ## Now let's ask some questions that start looking at the data itself...

# %%
sql_agent_executor.invoke('find all references to Mandalay Bay in all of the tables')
# Out:
# > Entering new SQL Agent Executor chain...
#
# Invoking: `sql_db_list_tables` with `{}`
#
#
# dol, ppp, sg
# Invoking: `sql_db_schema` with `{'table_names': 'dol'}`
#
#
#
# CREATE TABLE dol (
# 	"RECORD_TYPE" TEXT,
# 	"DATA_SOURCE" TEXT,
# 	"RECORD_ID" BIGINT,
# 	case_id BIGINT,
# 	"BUSINESS_NAME_ORG" TEXT,
# 	"LEGAL_NAME_ORG" TEXT,
# 	"BUSINESS_ADDR_LINE1" TEXT,
# 	"BUSINESS_ADDR_CITY" TEXT,
# 	"BUSINESS_ADDR_STATE" TEXT,
# 	"BUSINESS_ADDR_POSTAL_CODE" TEXT,
# 	naic_cd TEXT,
# 	naics_code_description TEXT,
# 	case_violtn_cnt BIGINT
# )
#
# /*
# 3 rows from dol table:
# RECORD_TYPE	DATA_SOURCE	RECORD_ID	case_id	BUSINESS_NAME_ORG	LEGAL_NAME_ORG	BUSINESS_ADDR_LINE1	BUSINESS_ADDR_CITY	BUSINESS_ADDR_STATE	BUSINESS_ADDR_POSTAL_CODE	naic_cd	naics_code_description	case_violtn_cnt
# ORGANIZATION	DoL_WHISARD	53	1658108	Fabulous Freddy's (Trailwood)	Fabulous LLC	9611 Trail Wood Drive	Las Vegas	NV	89134	811192	Car Washes	0
# ORGANIZATION	DoL_WHISARD	165	1419689	Boulder Station Hotel & Casino	Boulder Station, Inc.	4111 Boulder Hwy	Las Vegas	NV	89121	721120	Casino Hotels	1
# ORGANIZATION	DoL_WHISARD	178	1424856	MSI Landscaping	MIST Systems International, Inc.	4820 Quality Court, #B	Las Vegas	NV	89103	561730	Landscaping Services	14
# */
# Invoking: `sql_db_schema` with `{'table_names': 'ppp'}`
#
#
#
# CREATE TABLE ppp (
# 	"RECORD_TYPE" TEXT,
# 	"DATA_SOURCE" TEXT,
# 	"RECORD_ID" BIGINT,
# 	"Loan_Range" TEXT,
# 	"BUSINESS_NAME_ORG" TEXT,
# 	"BUSINESS_ADDR_LINE1" TEXT,
# 	"BUSINESS_ADDR_CITY" TEXT,
# 	"BUSINESS_ADDR_STATE" TEXT,
# 	"BUSINESS_ADDR_POSTAL_CODE" TEXT,
# 	"NAICS_Code" TEXT,
# 	"Business_Type" TEXT,
# 	"OwnedByRaceEthnicity" TEXT,
# 	"OwnedBy" TEXT,
# 	"OwnedByVeteran" TEXT,
# 	"NonProfit" TEXT,
# 	"JobsReported" TEXT,
# 	"DateApproved" TEXT,
# 	"Lender" TEXT,
# 	"CD" TEXT
# )
#
# /*
# 3 rows from ppp table:
# RECORD_TYPE	DATA_SOURCE	RECORD_ID	Loan_Range	BUSINESS_NAME_ORG	BUSINESS_ADDR_LINE1	BUSINESS_ADDR_CITY	BUSINESS_ADDR_STATE	BUSINESS_ADDR_POSTAL_CODE	NAICS_Code	Business_Type	OwnedByRaceEthnicity	OwnedBy	OwnedByVeteran	NonProfit	JobsReported	DateApproved	Lender	CD
# ORGANIZATION	PPP_LOANS	7017	c $1-2 million	INFINITY HOSPICE CARE OF LAS VEGAS, LLC	5110 N 40TH ST STE 107	PHOENIX	AZ	85018	623110	Limited  Liability Company(LLC)	Unanswered	Male Owned	Unanswered		137	05/01/2020	JPMorgan Chase Bank, National Association	AZ-09
# ORGANIZATION	PPP_LOANS	7018	d $350,000-1 million	CLUB TATTOO LAS VEGAS LLC	1839 s. almaschool rd. ste 230	MESA	AZ	85210	812199	Limited  Liability Company(LLC)	Unanswered	Male Owned	Non-Veteran		15	05/01/2020	JPMorgan Chase Bank, National Association	AZ-09
# ORGANIZATION	PPP_LOANS	7021	d $350,000-1 million	LAS VEGAS LABOR, LLC	10265 W Camelback Rd, Ste 104	PHOENIX	AZ	85037	111421	Limited  Liability Company(LLC)	Unanswered	Unanswered	Unanswered		0	04/07/2020	UMB Bank, National Association	AZ-03
# */
# Invoking: `sql_db_schema` with `{'table_names': 'sg'}`
#
#
#
# CREATE TABLE sg (
# 	"DATA_SOURCE" TEXT,
# 	"RECORD_ID" TEXT,
# 	"RECORD_TYPE" TEXT,
# 	"PLACEKEY" TEXT,
# 	"REL_ANCHOR_DOMAIN" TEXT,
# 	"REL_ANCHOR_KEY" TEXT,
# 	"LOCATION_NAME_ORG" TEXT,
# 	"BRANDS" TEXT,
# 	"TOP_CATEGORY" TEXT,
# 	"SUB_CATEGORY" TEXT,
# 	"NAICS_CODE" TEXT,
# 	"BUSINESS_GEO_LATITUDE" TEXT,
# 	"BUSINESS_GEO_LONGITUDE" TEXT,
# 	"CATEGORY_TAGS" TEXT,
# 	"CLOSED_ON" TEXT,
# 	"TRACKING_CLOSED_SINCE" TEXT,
# 	"PHONE_NUMBER" TEXT,
# 	"BUSINESS_ADDR_COUNTRY" TEXT,
# 	"BUSINESS_ADDR_FULL" TEXT,
# 	"MAILING_VERIFIED_STATUS" TEXT,
# 	"REL_POINTER_DOMAIN" TEXT,
# 	"REL_POINTER_KEY" TEXT,
# 	"REL_POINTER_ROLE" TEXT,
# 	"OPENED_ON" TEXT,
# 	"IS_INTERSECTION" TEXT
# )
#
# /*
# 3 rows from sg table:
# DATA_SOURCE	RECORD_ID	RECORD_TYPE	PLACEKEY	REL_ANCHOR_DOMAIN	REL_ANCHOR_KEY	LOCATION_NAME_ORG	BRANDS	TOP_CATEGORY	SUB_CATEGORY	NAICS_CODE	BUSINESS_GEO_LATITUDE	BUSINESS_GEO_LONGITUDE	CATEGORY_TAGS	CLOSED_ON	TRACKING_CLOSED_SINCE	PHONE_NUMBER	BUSINESS_ADDR_COUNTRY	BUSINESS_ADDR_FULL	MAILING_VERIFIED_STATUS	REL_POINTER_DOMAIN	REL_POINTER_KEY	REL_POINTER_ROLE	OPENED_ON	IS_INTERSECTION
# SAFEGRAPH	225-222@5yv-j92-tn5	ORGANIZATION	225-222@5yv-j92-tn5	PLACEKEY	225-222@5yv-j92-tn5	Cantwell Michelle L Atty	[]	Legal Services	Offices of Lawyers	541110	36.145647	-115.186399	[]	2024-02-01	2019-07-01	+17023627800	US	3320 W Sahara Ave Las Vegas NV 89102-3223	VERIFIED_PREMISE	None	None	None	None	None
# SAFEGRAPH	226-222@5yv-hmm-whq	ORGANIZATION	226-222@5yv-hmm-whq	PLACEKEY	226-222@5yv-hmm-whq	Pieology Pizzeria	[ { "safegraph_brand_id": "SG_BRAND_f372f9969f6e1ae119a13ff4fc78fd2d", "safegraph_brand_name": "Pieo	Restaurants and Other Eating Places	Limited-Service Restaurants	722513	36.144906	-115.332644	[ "Counter Service", "Dinner", "Fast Food", "Lunch", "Pizza" ]	None	2019-07-01	+17023314454	US	10965 Lavender Hill Dr Ste 130 Las Vegas NV 89135-2951	VERIFIED_DELIVERY_POINT	PLACEKEY	zzw-223@5yv-hkm-rc5	PARENT	None	None
# SAFEGRAPH	22s-222@5yv-jbz-jgk	ORGANIZATION	22s-222@5yv-jbz-jgk	PLACEKEY	22s-222@5yv-jbz-jgk	Ellen Peneyra	[]	Offices of Other Health Practitioners	Offices of All Other Miscellaneous Health Practitioners	621399	36.10289	-115.121807	[]	None	2019-07-01	+17027397716	US	2275 Renaissance Dr Ste D Las Vegas NV 89119-6797	VERIFIED_DELIVERY_POINT	PLACEKEY	22g-222@5yv-jbz-h89	PARENT	None	None
# */
# Invoking: `sql_db_query_checker` with `{'query': "SELECT BUSINESS_NAME_ORG, LEGAL_NAME_ORG, BUSINESS_ADDR_LINE1, BUSINESS_ADDR_CITY, BUSINESS_ADDR_STATE FROM dol WHERE BUSINESS_NAME_ORG LIKE '%Mandalay Bay%' OR LEGAL_NAME_ORG LIKE '%Mandalay Bay%' OR BUSINESS_ADDR_LINE1 LIKE '%Mandalay Bay%' LIMIT 10;"}`
# responded: The database contains three tables: `dol`, `ppp`, and `sg`. Each table has columns that might contain references to "Mandalay Bay". I will query each table to find any references to "Mandalay Bay".
#
# Let's start by querying the `dol` table.
#
# ```sql
# SELECT BUSINESS_NAME_ORG, LEGAL_NAME_ORG, BUSINESS_ADDR_LINE1, BUSINESS_ADDR_CITY, BUSINESS_ADDR_STATE
# FROM dol
# WHERE BUSINESS_NAME_ORG LIKE '%Mandalay Bay%'
#    OR LEGAL_NAME_ORG LIKE '%Mandalay Bay%'
#    OR BUSINESS_ADDR_LINE1 LIKE '%Mandalay Bay%'
# LIMIT 10;
# ```
# Invoking: `sql_db_query` with `{'query': "SELECT BUSINESS_NAME_ORG, LEGAL_NAME_ORG, BUSINESS_ADDR_LINE1, BUSINESS_ADDR_CITY, BUSINESS_ADDR_STATE FROM dol WHERE BUSINESS_NAME_ORG LIKE '%Mandalay Bay%' OR LEGAL_NAME_ORG LIKE '%Mandalay Bay%' OR BUSINESS_ADDR_LINE1 LIKE '%Mandalay Bay%' LIMIT 10;"}`
#
#
# [('Mandalay Bay Casino', 'Mandalay Corporation', '3950 S. Las Vegas Blvd.', 'Las Vegas', 'NV'), ('Mandalay Bay Hotel & Casino', 'Mandalay Corporation', '3950 Las Vegas Blvd, S', 'Las Vegas', 'NV'), ('Mandalay Bay Resort & Casino', 'Mandalay Bay Resort & Casino', '3950 Las Vegas Blvd South', 'Las Vegas', 'NV'), ('Mandalay Bay Casino and Resort', 'Mandalay Corp', '3950 S Las Vegas Blvd', 'Las Vegas', 'NV'), ('Mandalay Bay Resort and Casino', 'Mandalay Bay Corporation', '3950 Las Vegas Blvd S', 'Las Vegas', 'NV'), ('Mandalay Bay', 'Mandalay Corp', '3950 S Las Vegas Blvd', 'Las Vegas', 'NV'), ('Mandalay Bay', 'Manadalay Corp,', '3950 S. Las Vegas Blvd', 'Las Vegas', 'NV'), ('Mandalay Bay', 'Mandalay Bay Resort & Casino', '3950 Las Vegas Blvd.  South', 'Las Vegas', 'NV'), ('Mandalay Corp', 'Mandalay Bay Resort & Casino', '3950 Las Vegas Blvd S.', 'Las Vegas', 'NV'), ('Mandalay Bay Hotel & Casino', 'Mandalay Corp.', '3600 Las Vegas Blvd S.', 'Las Vegas', 'NV')]
# Invoking: `sql_db_query_checker` with `{'query': "SELECT BUSINESS_NAME_ORG, BUSINESS_ADDR_LINE1, BUSINESS_ADDR_CITY, BUSINESS_ADDR_STATE FROM ppp WHERE BUSINESS_NAME_ORG LIKE '%Mandalay Bay%' OR BUSINESS_ADDR_LINE1 LIKE '%Mandalay Bay%' LIMIT 10;"}`
# responded: Here are the references to "Mandalay Bay" found in the `dol` table:
#
# 1. **Business Name:** Mandalay Bay Casino
#    - **Legal Name:** Mandalay Corporation
#    - **Address:** 3950 S. Las Vegas Blvd., Las Vegas, NV
#
# 2. **Business Name:** Mandalay Bay Hotel & Casino
#    - **Legal Name:** Mandalay Corporation
#    - **Address:** 3950 Las Vegas Blvd, S, Las Vegas, NV
#
# 3. **Business Name:** Mandalay Bay Resort & Casino
#    - **Legal Name:** Mandalay Bay Resort & Casino
#    - **Address:** 3950 Las Vegas Blvd South, Las Vegas, NV
#
# 4. **Business Name:** Mandalay Bay Casino and Resort
#    - **Legal Name:** Mandalay Corp
#    - **Address:** 3950 S Las Vegas Blvd, Las Vegas, NV
#
# 5. **Business Name:** Mandalay Bay Resort and Casino
#    - **Legal Name:** Mandalay Bay Corporation
#    - **Address:** 3950 Las Vegas Blvd S, Las Vegas, NV
#
# 6. **Business Name:** Mandalay Bay
#    - **Legal Name:** Mandalay Corp
#    - **Address:** 3950 S Las Vegas Blvd, Las Vegas, NV
#
# 7. **Business Name:** Mandalay Bay
#    - **Legal Name:** Manadalay Corp,
#    - **Address:** 3950 S. Las Vegas Blvd, Las Vegas, NV
#
# 8. **Business Name:** Mandalay Bay
#    - **Legal Name:** Mandalay Bay Resort & Casino
#    - **Address:** 3950 Las Vegas Blvd. South, Las Vegas, NV
#
# 9. **Business Name:** Mandalay Corp
#    - **Legal Name:** Mandalay Bay Resort & Casino
#    - **Address:** 3950 Las Vegas Blvd S., Las Vegas, NV
#
# 10. **Business Name:** Mandalay Bay Hotel & Casino
#     - **Legal Name:** Mandalay Corp.
#     - **Address:** 3600 Las Vegas Blvd S., Las Vegas, NV
#
# Next, I will query the `ppp` table.
#
# ```sql
# SELECT BUSINESS_NAME_ORG, BUSINESS_ADDR_LINE1, BUSINESS_ADDR_CITY, BUSINESS_ADDR_STATE
# FROM ppp
# WHERE BUSINESS_NAME_ORG LIKE '%Mandalay Bay%'
#    OR BUSINESS_ADDR_LINE1 LIKE '%Mandalay Bay%'
# LIMIT 10;
# ```
# Invoking: `sql_db_query` with `{'query': "SELECT BUSINESS_NAME_ORG, BUSINESS_ADDR_LINE1, BUSINESS_ADDR_CITY, BUSINESS_ADDR_STATE FROM ppp WHERE BUSINESS_NAME_ORG LIKE '%Mandalay Bay%' OR BUSINESS_ADDR_LINE1 LIKE '%Mandalay Bay%' LIMIT 10;"}`
#
#
#
# Invoking: `sql_db_query_checker` with `{'query': "SELECT LOCATION_NAME_ORG, BUSINESS_ADDR_FULL FROM sg WHERE LOCATION_NAME_ORG LIKE '%Mandalay Bay%' OR BUSINESS_ADDR_FULL LIKE '%Mandalay Bay%' LIMIT 10;"}`
# responded: There are no references to "Mandalay Bay" found in the `ppp` table.
#
# Finally, I will query the `sg` table.
#
# ```sql
# SELECT LOCATION_NAME_ORG, BUSINESS_ADDR_FULL
# FROM sg
# WHERE LOCATION_NAME_ORG LIKE '%Mandalay Bay%'
#    OR BUSINESS_ADDR_FULL LIKE '%Mandalay Bay%'
# LIMIT 10;
# ```
# Invoking: `sql_db_query` with `{'query': "SELECT LOCATION_NAME_ORG, BUSINESS_ADDR_FULL FROM sg WHERE LOCATION_NAME_ORG LIKE '%Mandalay Bay%' OR BUSINESS_ADDR_FULL LIKE '%Mandalay Bay%' LIMIT 10;"}`
#
#
# [('Mandalay Bay Sports Book', '3950 Las Vegas Blvd S Las Vegas NV 89119-1005'), ('The Gym At Mandalay Bay', '3930 Las Vegas Blvd S Las Vegas NV 89119-1010'), ('Mandalay Bay Resort & Casino', '3960 Las Vegas Blvd S Las Vegas NV 89119-1046'), ('Mandalay Bay Self Parking', '3930 Las Vegas Blvd S Las Vegas NV 89119-1010'), ('Mandalay Bay Parking Garage', None), ('Kalologie Medspa at Mandalay Bay', '3950 Las Vegas Blvd S Las Vegas NV 89119-1005'), ('Regional Transportation Commission of Southern Nevada SB Las Vegas at Mandalay Bay', None), ('Hotels In Las Vegas Vegas Hotels Mandalay Bay Resort & Casino', '3950 Las Vegas Blvd S Las Vegas NV 89119-1005'), ('Kalologie Medspa Mandalay Bay IV Therapy & More', '3950 Las Vegas Blvd S Las Vegas NV 89119-1005'), ("Bonanno's New York Pizzeria Mandalay Bay", '3950 Las Vegas Blvd S Las Vegas NV 89119-1005')]Here are the references to "Mandalay Bay" found in the `sg` table:
#
# 1. **Location Name:** Mandalay Bay Sports Book
#    - **Address:** 3950 Las Vegas Blvd S, Las Vegas, NV 89119-1005
#
# 2. **Location Name:** The Gym At Mandalay Bay
#    - **Address:** 3930 Las Vegas Blvd S, Las Vegas, NV 89119-1010
#
# 3. **Location Name:** Mandalay Bay Resort & Casino
#    - **Address:** 3960 Las Vegas Blvd S, Las Vegas, NV 89119-1046
#
# 4. **Location Name:** Mandalay Bay Self Parking
#    - **Address:** 3930 Las Vegas Blvd S, Las Vegas, NV 89119-1010
#
# 5. **Location Name:** Mandalay Bay Parking Garage
#    - **Address:** Not available
#
# 6. **Location Name:** Kalologie Medspa at Mandalay Bay
#    - **Address:** 3950 Las Vegas Blvd S, Las Vegas, NV 89119-1005
#
# 7. **Location Name:** Regional Transportation Commission of Southern Nevada SB Las Vegas at Mandalay Bay
#    - **Address:** Not available
#
# 8. **Location Name:** Hotels In Las Vegas Vegas Hotels Mandalay Bay Resort & Casino
#    - **Address:** 3950 Las Vegas Blvd S, Las Vegas, NV 89119-1005
#
# 9. **Location Name:** Kalologie Medspa Mandalay Bay IV Therapy & More
#    - **Address:** 3950 Las Vegas Blvd S, Las Vegas, NV 89119-1005
#
# 10. **Location Name:** Bonanno's New York Pizzeria Mandalay Bay
#     - **Address:** 3950 Las Vegas Blvd S, Las Vegas, NV 89119-1005
#
# In summary, references to "Mandalay Bay" were found in both the `dol` and `sg` tables, but not in the `ppp` table.
#
# > Finished chain.
# {'input': 'find all references to Mandalay Bay in all of the tables',
#  'output': 'Here are the references to "Mandalay Bay" found in the `sg` table:\n\n1. **Location Name:** Mandalay Bay Sports Book\n   - **Address:** 3950 Las Vegas Blvd S, Las Vegas, NV 89119-1005\n\n2. **Location Name:** The Gym At Mandalay Bay\n   - **Address:** 3930 Las Vegas Blvd S, Las Vegas, NV 89119-1010\n\n3. **Location Name:** Mandalay Bay Resort & Casino\n   - **Address:** 3960 Las Vegas Blvd S, Las Vegas, NV 89119-1046\n\n4. **Location Name:** Mandalay Bay Self Parking\n   - **Address:** 3930 Las Vegas Blvd S, Las Vegas, NV 89119-1010\n\n5. **Location Name:** Mandalay Bay Parking Garage\n   - **Address:** Not available\n\n6. **Location Name:** Kalologie Medspa at Mandalay Bay\n   - **Address:** 3950 Las Vegas Blvd S, Las Vegas, NV 89119-1005\n\n7. **Location Name:** Regional Transportation Commission of Southern Nevada SB Las Vegas at Mandalay Bay\n   - **Address:** Not available\n\n8. **Location Name:** Hotels In Las Vegas Vegas Hotels Mandalay Bay Resort & Casino\n   - **Address:** 3950 Las Vegas Blvd S, Las Vegas, NV 89119-1005\n\n9. **Location Name:** Kalologie Medspa Mandalay Bay IV Therapy & More\n   - **Address:** 3950 Las Vegas Blvd S, Las Vegas, NV 89119-1005\n\n10. **Location Name:** Bonanno\'s New York Pizzeria Mandalay Bay\n    - **Address:** 3950 Las Vegas Blvd S, Las Vegas, NV 89119-1005\n\nIn summary, references to "Mandalay Bay" were found in both the `dol` and `sg` tables, but not in the `ppp` table.'}

# %%
sql_agent_executor.invoke('does Mandalay Bay have any violations?')
# Out:
# > Entering new SQL Agent Executor chain...
#
# Invoking: `sql_db_list_tables` with `{}`
#
#
# dol, ppp, sg
# Invoking: `sql_db_schema` with `{'table_names': 'dol, ppp, sg'}`
#
#
#
# CREATE TABLE dol (
# 	"RECORD_TYPE" TEXT,
# 	"DATA_SOURCE" TEXT,
# 	"RECORD_ID" BIGINT,
# 	case_id BIGINT,
# 	"BUSINESS_NAME_ORG" TEXT,
# 	"LEGAL_NAME_ORG" TEXT,
# 	"BUSINESS_ADDR_LINE1" TEXT,
# 	"BUSINESS_ADDR_CITY" TEXT,
# 	"BUSINESS_ADDR_STATE" TEXT,
# 	"BUSINESS_ADDR_POSTAL_CODE" TEXT,
# 	naic_cd TEXT,
# 	naics_code_description TEXT,
# 	case_violtn_cnt BIGINT
# )
#
# /*
# 3 rows from dol table:
# RECORD_TYPE	DATA_SOURCE	RECORD_ID	case_id	BUSINESS_NAME_ORG	LEGAL_NAME_ORG	BUSINESS_ADDR_LINE1	BUSINESS_ADDR_CITY	BUSINESS_ADDR_STATE	BUSINESS_ADDR_POSTAL_CODE	naic_cd	naics_code_description	case_violtn_cnt
# ORGANIZATION	DoL_WHISARD	53	1658108	Fabulous Freddy's (Trailwood)	Fabulous LLC	9611 Trail Wood Drive	Las Vegas	NV	89134	811192	Car Washes	0
# ORGANIZATION	DoL_WHISARD	165	1419689	Boulder Station Hotel & Casino	Boulder Station, Inc.	4111 Boulder Hwy	Las Vegas	NV	89121	721120	Casino Hotels	1
# ORGANIZATION	DoL_WHISARD	178	1424856	MSI Landscaping	MIST Systems International, Inc.	4820 Quality Court, #B	Las Vegas	NV	89103	561730	Landscaping Services	14
# */
#
#
# CREATE TABLE ppp (
# 	"RECORD_TYPE" TEXT,
# 	"DATA_SOURCE" TEXT,
# 	"RECORD_ID" BIGINT,
# 	"Loan_Range" TEXT,
# 	"BUSINESS_NAME_ORG" TEXT,
# 	"BUSINESS_ADDR_LINE1" TEXT,
# 	"BUSINESS_ADDR_CITY" TEXT,
# 	"BUSINESS_ADDR_STATE" TEXT,
# 	"BUSINESS_ADDR_POSTAL_CODE" TEXT,
# 	"NAICS_Code" TEXT,
# 	"Business_Type" TEXT,
# 	"OwnedByRaceEthnicity" TEXT,
# 	"OwnedBy" TEXT,
# 	"OwnedByVeteran" TEXT,
# 	"NonProfit" TEXT,
# 	"JobsReported" TEXT,
# 	"DateApproved" TEXT,
# 	"Lender" TEXT,
# 	"CD" TEXT
# )
#
# /*
# 3 rows from ppp table:
# RECORD_TYPE	DATA_SOURCE	RECORD_ID	Loan_Range	BUSINESS_NAME_ORG	BUSINESS_ADDR_LINE1	BUSINESS_ADDR_CITY	BUSINESS_ADDR_STATE	BUSINESS_ADDR_POSTAL_CODE	NAICS_Code	Business_Type	OwnedByRaceEthnicity	OwnedBy	OwnedByVeteran	NonProfit	JobsReported	DateApproved	Lender	CD
# ORGANIZATION	PPP_LOANS	7017	c $1-2 million	INFINITY HOSPICE CARE OF LAS VEGAS, LLC	5110 N 40TH ST STE 107	PHOENIX	AZ	85018	623110	Limited  Liability Company(LLC)	Unanswered	Male Owned	Unanswered		137	05/01/2020	JPMorgan Chase Bank, National Association	AZ-09
# ORGANIZATION	PPP_LOANS	7018	d $350,000-1 million	CLUB TATTOO LAS VEGAS LLC	1839 s. almaschool rd. ste 230	MESA	AZ	85210	812199	Limited  Liability Company(LLC)	Unanswered	Male Owned	Non-Veteran		15	05/01/2020	JPMorgan Chase Bank, National Association	AZ-09
# ORGANIZATION	PPP_LOANS	7021	d $350,000-1 million	LAS VEGAS LABOR, LLC	10265 W Camelback Rd, Ste 104	PHOENIX	AZ	85037	111421	Limited  Liability Company(LLC)	Unanswered	Unanswered	Unanswered		0	04/07/2020	UMB Bank, National Association	AZ-03
# */
#
#
# CREATE TABLE sg (
# 	"DATA_SOURCE" TEXT,
# 	"RECORD_ID" TEXT,
# 	"RECORD_TYPE" TEXT,
# 	"PLACEKEY" TEXT,
# 	"REL_ANCHOR_DOMAIN" TEXT,
# 	"REL_ANCHOR_KEY" TEXT,
# 	"LOCATION_NAME_ORG" TEXT,
# 	"BRANDS" TEXT,
# 	"TOP_CATEGORY" TEXT,
# 	"SUB_CATEGORY" TEXT,
# 	"NAICS_CODE" TEXT,
# 	"BUSINESS_GEO_LATITUDE" TEXT,
# 	"BUSINESS_GEO_LONGITUDE" TEXT,
# 	"CATEGORY_TAGS" TEXT,
# 	"CLOSED_ON" TEXT,
# 	"TRACKING_CLOSED_SINCE" TEXT,
# 	"PHONE_NUMBER" TEXT,
# 	"BUSINESS_ADDR_COUNTRY" TEXT,
# 	"BUSINESS_ADDR_FULL" TEXT,
# 	"MAILING_VERIFIED_STATUS" TEXT,
# 	"REL_POINTER_DOMAIN" TEXT,
# 	"REL_POINTER_KEY" TEXT,
# 	"REL_POINTER_ROLE" TEXT,
# 	"OPENED_ON" TEXT,
# 	"IS_INTERSECTION" TEXT
# )
#
# /*
# 3 rows from sg table:
# DATA_SOURCE	RECORD_ID	RECORD_TYPE	PLACEKEY	REL_ANCHOR_DOMAIN	REL_ANCHOR_KEY	LOCATION_NAME_ORG	BRANDS	TOP_CATEGORY	SUB_CATEGORY	NAICS_CODE	BUSINESS_GEO_LATITUDE	BUSINESS_GEO_LONGITUDE	CATEGORY_TAGS	CLOSED_ON	TRACKING_CLOSED_SINCE	PHONE_NUMBER	BUSINESS_ADDR_COUNTRY	BUSINESS_ADDR_FULL	MAILING_VERIFIED_STATUS	REL_POINTER_DOMAIN	REL_POINTER_KEY	REL_POINTER_ROLE	OPENED_ON	IS_INTERSECTION
# SAFEGRAPH	225-222@5yv-j92-tn5	ORGANIZATION	225-222@5yv-j92-tn5	PLACEKEY	225-222@5yv-j92-tn5	Cantwell Michelle L Atty	[]	Legal Services	Offices of Lawyers	541110	36.145647	-115.186399	[]	2024-02-01	2019-07-01	+17023627800	US	3320 W Sahara Ave Las Vegas NV 89102-3223	VERIFIED_PREMISE	None	None	None	None	None
# SAFEGRAPH	226-222@5yv-hmm-whq	ORGANIZATION	226-222@5yv-hmm-whq	PLACEKEY	226-222@5yv-hmm-whq	Pieology Pizzeria	[ { "safegraph_brand_id": "SG_BRAND_f372f9969f6e1ae119a13ff4fc78fd2d", "safegraph_brand_name": "Pieo	Restaurants and Other Eating Places	Limited-Service Restaurants	722513	36.144906	-115.332644	[ "Counter Service", "Dinner", "Fast Food", "Lunch", "Pizza" ]	None	2019-07-01	+17023314454	US	10965 Lavender Hill Dr Ste 130 Las Vegas NV 89135-2951	VERIFIED_DELIVERY_POINT	PLACEKEY	zzw-223@5yv-hkm-rc5	PARENT	None	None
# SAFEGRAPH	22s-222@5yv-jbz-jgk	ORGANIZATION	22s-222@5yv-jbz-jgk	PLACEKEY	22s-222@5yv-jbz-jgk	Ellen Peneyra	[]	Offices of Other Health Practitioners	Offices of All Other Miscellaneous Health Practitioners	621399	36.10289	-115.121807	[]	None	2019-07-01	+17027397716	US	2275 Renaissance Dr Ste D Las Vegas NV 89119-6797	VERIFIED_DELIVERY_POINT	PLACEKEY	22g-222@5yv-jbz-h89	PARENT	None	None
# */
# Invoking: `sql_db_query_checker` with `{'query': "SELECT BUSINESS_NAME_ORG, case_violtn_cnt FROM dol WHERE BUSINESS_NAME_ORG = 'Mandalay Bay'"}`
#
#
# ```sql
# SELECT BUSINESS_NAME_ORG, case_violtn_cnt
# FROM dol
# WHERE BUSINESS_NAME_ORG = 'Mandalay Bay';
# ```
# Invoking: `sql_db_query` with `{'query': "SELECT BUSINESS_NAME_ORG, case_violtn_cnt FROM dol WHERE BUSINESS_NAME_ORG = 'Mandalay Bay'"}`
#
#
# [('Mandalay Bay', 0), ('Mandalay Bay', 2), ('Mandalay Bay', 0)]Yes, Mandalay Bay has violations. Here are the details:
#
# - One record shows 2 violations.
# - Two records show 0 violations.
#
# > Finished chain.
# {'input': 'does Mandalay Bay have any violations?',
#  'output': 'Yes, Mandalay Bay has violations. Here are the details:\n\n- One record shows 2 violations.\n- Two records show 0 violations.'}

# %%
sql_agent_executor.invoke('which company has the most violations?')
# Out:
# > Entering new SQL Agent Executor chain...
#
# Invoking: `sql_db_list_tables` with `{}`
#
#
# dol, ppp, sg
# Invoking: `sql_db_schema` with `{'table_names': 'dol'}`
#
#
#
# CREATE TABLE dol (
# 	"RECORD_TYPE" TEXT,
# 	"DATA_SOURCE" TEXT,
# 	"RECORD_ID" BIGINT,
# 	case_id BIGINT,
# 	"BUSINESS_NAME_ORG" TEXT,
# 	"LEGAL_NAME_ORG" TEXT,
# 	"BUSINESS_ADDR_LINE1" TEXT,
# 	"BUSINESS_ADDR_CITY" TEXT,
# 	"BUSINESS_ADDR_STATE" TEXT,
# 	"BUSINESS_ADDR_POSTAL_CODE" TEXT,
# 	naic_cd TEXT,
# 	naics_code_description TEXT,
# 	case_violtn_cnt BIGINT
# )
#
# /*
# 3 rows from dol table:
# RECORD_TYPE	DATA_SOURCE	RECORD_ID	case_id	BUSINESS_NAME_ORG	LEGAL_NAME_ORG	BUSINESS_ADDR_LINE1	BUSINESS_ADDR_CITY	BUSINESS_ADDR_STATE	BUSINESS_ADDR_POSTAL_CODE	naic_cd	naics_code_description	case_violtn_cnt
# ORGANIZATION	DoL_WHISARD	53	1658108	Fabulous Freddy's (Trailwood)	Fabulous LLC	9611 Trail Wood Drive	Las Vegas	NV	89134	811192	Car Washes	0
# ORGANIZATION	DoL_WHISARD	165	1419689	Boulder Station Hotel & Casino	Boulder Station, Inc.	4111 Boulder Hwy	Las Vegas	NV	89121	721120	Casino Hotels	1
# ORGANIZATION	DoL_WHISARD	178	1424856	MSI Landscaping	MIST Systems International, Inc.	4820 Quality Court, #B	Las Vegas	NV	89103	561730	Landscaping Services	14
# */
# Invoking: `sql_db_schema` with `{'table_names': 'ppp'}`
#
#
#
# CREATE TABLE ppp (
# 	"RECORD_TYPE" TEXT,
# 	"DATA_SOURCE" TEXT,
# 	"RECORD_ID" BIGINT,
# 	"Loan_Range" TEXT,
# 	"BUSINESS_NAME_ORG" TEXT,
# 	"BUSINESS_ADDR_LINE1" TEXT,
# 	"BUSINESS_ADDR_CITY" TEXT,
# 	"BUSINESS_ADDR_STATE" TEXT,
# 	"BUSINESS_ADDR_POSTAL_CODE" TEXT,
# 	"NAICS_Code" TEXT,
# 	"Business_Type" TEXT,
# 	"OwnedByRaceEthnicity" TEXT,
# 	"OwnedBy" TEXT,
# 	"OwnedByVeteran" TEXT,
# 	"NonProfit" TEXT,
# 	"JobsReported" TEXT,
# 	"DateApproved" TEXT,
# 	"Lender" TEXT,
# 	"CD" TEXT
# )
#
# /*
# 3 rows from ppp table:
# RECORD_TYPE	DATA_SOURCE	RECORD_ID	Loan_Range	BUSINESS_NAME_ORG	BUSINESS_ADDR_LINE1	BUSINESS_ADDR_CITY	BUSINESS_ADDR_STATE	BUSINESS_ADDR_POSTAL_CODE	NAICS_Code	Business_Type	OwnedByRaceEthnicity	OwnedBy	OwnedByVeteran	NonProfit	JobsReported	DateApproved	Lender	CD
# ORGANIZATION	PPP_LOANS	7017	c $1-2 million	INFINITY HOSPICE CARE OF LAS VEGAS, LLC	5110 N 40TH ST STE 107	PHOENIX	AZ	85018	623110	Limited  Liability Company(LLC)	Unanswered	Male Owned	Unanswered		137	05/01/2020	JPMorgan Chase Bank, National Association	AZ-09
# ORGANIZATION	PPP_LOANS	7018	d $350,000-1 million	CLUB TATTOO LAS VEGAS LLC	1839 s. almaschool rd. ste 230	MESA	AZ	85210	812199	Limited  Liability Company(LLC)	Unanswered	Male Owned	Non-Veteran		15	05/01/2020	JPMorgan Chase Bank, National Association	AZ-09
# ORGANIZATION	PPP_LOANS	7021	d $350,000-1 million	LAS VEGAS LABOR, LLC	10265 W Camelback Rd, Ste 104	PHOENIX	AZ	85037	111421	Limited  Liability Company(LLC)	Unanswered	Unanswered	Unanswered		0	04/07/2020	UMB Bank, National Association	AZ-03
# */
# Invoking: `sql_db_schema` with `{'table_names': 'sg'}`
#
#
#
# CREATE TABLE sg (
# 	"DATA_SOURCE" TEXT,
# 	"RECORD_ID" TEXT,
# 	"RECORD_TYPE" TEXT,
# 	"PLACEKEY" TEXT,
# 	"REL_ANCHOR_DOMAIN" TEXT,
# 	"REL_ANCHOR_KEY" TEXT,
# 	"LOCATION_NAME_ORG" TEXT,
# 	"BRANDS" TEXT,
# 	"TOP_CATEGORY" TEXT,
# 	"SUB_CATEGORY" TEXT,
# 	"NAICS_CODE" TEXT,
# 	"BUSINESS_GEO_LATITUDE" TEXT,
# 	"BUSINESS_GEO_LONGITUDE" TEXT,
# 	"CATEGORY_TAGS" TEXT,
# 	"CLOSED_ON" TEXT,
# 	"TRACKING_CLOSED_SINCE" TEXT,
# 	"PHONE_NUMBER" TEXT,
# 	"BUSINESS_ADDR_COUNTRY" TEXT,
# 	"BUSINESS_ADDR_FULL" TEXT,
# 	"MAILING_VERIFIED_STATUS" TEXT,
# 	"REL_POINTER_DOMAIN" TEXT,
# 	"REL_POINTER_KEY" TEXT,
# 	"REL_POINTER_ROLE" TEXT,
# 	"OPENED_ON" TEXT,
# 	"IS_INTERSECTION" TEXT
# )
#
# /*
# 3 rows from sg table:
# DATA_SOURCE	RECORD_ID	RECORD_TYPE	PLACEKEY	REL_ANCHOR_DOMAIN	REL_ANCHOR_KEY	LOCATION_NAME_ORG	BRANDS	TOP_CATEGORY	SUB_CATEGORY	NAICS_CODE	BUSINESS_GEO_LATITUDE	BUSINESS_GEO_LONGITUDE	CATEGORY_TAGS	CLOSED_ON	TRACKING_CLOSED_SINCE	PHONE_NUMBER	BUSINESS_ADDR_COUNTRY	BUSINESS_ADDR_FULL	MAILING_VERIFIED_STATUS	REL_POINTER_DOMAIN	REL_POINTER_KEY	REL_POINTER_ROLE	OPENED_ON	IS_INTERSECTION
# SAFEGRAPH	225-222@5yv-j92-tn5	ORGANIZATION	225-222@5yv-j92-tn5	PLACEKEY	225-222@5yv-j92-tn5	Cantwell Michelle L Atty	[]	Legal Services	Offices of Lawyers	541110	36.145647	-115.186399	[]	2024-02-01	2019-07-01	+17023627800	US	3320 W Sahara Ave Las Vegas NV 89102-3223	VERIFIED_PREMISE	None	None	None	None	None
# SAFEGRAPH	226-222@5yv-hmm-whq	ORGANIZATION	226-222@5yv-hmm-whq	PLACEKEY	226-222@5yv-hmm-whq	Pieology Pizzeria	[ { "safegraph_brand_id": "SG_BRAND_f372f9969f6e1ae119a13ff4fc78fd2d", "safegraph_brand_name": "Pieo	Restaurants and Other Eating Places	Limited-Service Restaurants	722513	36.144906	-115.332644	[ "Counter Service", "Dinner", "Fast Food", "Lunch", "Pizza" ]	None	2019-07-01	+17023314454	US	10965 Lavender Hill Dr Ste 130 Las Vegas NV 89135-2951	VERIFIED_DELIVERY_POINT	PLACEKEY	zzw-223@5yv-hkm-rc5	PARENT	None	None
# SAFEGRAPH	22s-222@5yv-jbz-jgk	ORGANIZATION	22s-222@5yv-jbz-jgk	PLACEKEY	22s-222@5yv-jbz-jgk	Ellen Peneyra	[]	Offices of Other Health Practitioners	Offices of All Other Miscellaneous Health Practitioners	621399	36.10289	-115.121807	[]	None	2019-07-01	+17027397716	US	2275 Renaissance Dr Ste D Las Vegas NV 89119-6797	VERIFIED_DELIVERY_POINT	PLACEKEY	22g-222@5yv-jbz-h89	PARENT	None	None
# */
# Invoking: `sql_db_query_checker` with `{'query': 'SELECT BUSINESS_NAME_ORG, SUM(case_violtn_cnt) AS total_violations FROM dol GROUP BY BUSINESS_NAME_ORG ORDER BY total_violations DESC LIMIT 10;'}`
# responded: The `dol` table contains information about violations, specifically in the `case_violtn_cnt` column. I will query this table to find the company with the most violations.
#
# Let's construct the query to find the company with the most violations.
#
# ```sql
# SELECT BUSINESS_NAME_ORG, SUM(case_violtn_cnt) AS total_violations
# FROM dol
# GROUP BY BUSINESS_NAME_ORG
# ORDER BY total_violations DESC
# LIMIT 10;
# ```
# Invoking: `sql_db_query` with `{'query': 'SELECT BUSINESS_NAME_ORG, SUM(case_violtn_cnt) AS total_violations FROM dol GROUP BY BUSINESS_NAME_ORG ORDER BY total_violations DESC LIMIT 10;'}`
#
#
# [('MGM Grand Hotel & Casino', 16468), ('Marquis Care Plaza Regency', 12000), ('Suncoast Hotel & Casino', 3273), ('C Martin Company Inc', 1177), ('Desert Plastering, LLC', 1060), ('One Stop Motors.Com', 1026), ('WestCor Construction', 933), ('Garris Plastering', 723), ('Checker Cab Company', 685), ('Westgate Marketing', 680)]The company with the most violations is **MGM Grand Hotel & Casino** with a total of 16,468 violations. Here are the top 10 companies with the most violations:
#
# 1. MGM Grand Hotel & Casino - 16,468 violations
# 2. Marquis Care Plaza Regency - 12,000 violations
# 3. Suncoast Hotel & Casino - 3,273 violations
# 4. C Martin Company Inc - 1,177 violations
# 5. Desert Plastering, LLC - 1,060 violations
# 6. One Stop Motors.Com - 1,026 violations
# 7. WestCor Construction - 933 violations
# 8. Garris Plastering - 723 violations
# 9. Checker Cab Company - 685 violations
# 10. Westgate Marketing - 680 violations
#
# > Finished chain.
# {'input': 'which company has the most violations?',
#  'output': 'The company with the most violations is **MGM Grand Hotel & Casino** with a total of 16,468 violations. Here are the top 10 companies with the most violations:\n\n1. MGM Grand Hotel & Casino - 16,468 violations\n2. Marquis Care Plaza Regency - 12,000 violations\n3. Suncoast Hotel & Casino - 3,273 violations\n4. C Martin Company Inc - 1,177 violations\n5. Desert Plastering, LLC - 1,060 violations\n6. One Stop Motors.Com - 1,026 violations\n7. WestCor Construction - 933 violations\n8. Garris Plastering - 723 violations\n9. Checker Cab Company - 685 violations\n10. Westgate Marketing - 680 violations'}

# %% [markdown]
# ## Uh oh!
#
# Houston, we have a problem!
#
# According to these basic SQL queries, Mandalay Bay has only a few violations.  While that is true for these very specific rows, it misses the fact that Mandalay Bay is owned by MGM Grand, which has the most violations!  So if you were wanting to get an accurate accounting of those violations (or many other questions you could think of to ask this data), you will miss it because you have not resolved the fact of the parent relationship between MGM Grand and Mandalay Bay!
#
# ### Now let's ask something a little more complicated...

# %%
sql_agent_executor.invoke('of the companies that took on the biggest loans, which had the most violations?')
# Out:
# > Entering new SQL Agent Executor chain...
#
# Invoking: `sql_db_list_tables` with `{}`
#
#
# dol, ppp, sg
# Invoking: `sql_db_schema` with `{'table_names': 'dol'}`
#
#
#
# CREATE TABLE dol (
# 	"RECORD_TYPE" TEXT,
# 	"DATA_SOURCE" TEXT,
# 	"RECORD_ID" BIGINT,
# 	case_id BIGINT,
# 	"BUSINESS_NAME_ORG" TEXT,
# 	"LEGAL_NAME_ORG" TEXT,
# 	"BUSINESS_ADDR_LINE1" TEXT,
# 	"BUSINESS_ADDR_CITY" TEXT,
# 	"BUSINESS_ADDR_STATE" TEXT,
# 	"BUSINESS_ADDR_POSTAL_CODE" TEXT,
# 	naic_cd TEXT,
# 	naics_code_description TEXT,
# 	case_violtn_cnt BIGINT
# )
#
# /*
# 3 rows from dol table:
# RECORD_TYPE	DATA_SOURCE	RECORD_ID	case_id	BUSINESS_NAME_ORG	LEGAL_NAME_ORG	BUSINESS_ADDR_LINE1	BUSINESS_ADDR_CITY	BUSINESS_ADDR_STATE	BUSINESS_ADDR_POSTAL_CODE	naic_cd	naics_code_description	case_violtn_cnt
# ORGANIZATION	DoL_WHISARD	53	1658108	Fabulous Freddy's (Trailwood)	Fabulous LLC	9611 Trail Wood Drive	Las Vegas	NV	89134	811192	Car Washes	0
# ORGANIZATION	DoL_WHISARD	165	1419689	Boulder Station Hotel & Casino	Boulder Station, Inc.	4111 Boulder Hwy	Las Vegas	NV	89121	721120	Casino Hotels	1
# ORGANIZATION	DoL_WHISARD	178	1424856	MSI Landscaping	MIST Systems International, Inc.	4820 Quality Court, #B	Las Vegas	NV	89103	561730	Landscaping Services	14
# */
# Invoking: `sql_db_schema` with `{'table_names': 'ppp'}`
#
#
#
# CREATE TABLE ppp (
# 	"RECORD_TYPE" TEXT,
# 	"DATA_SOURCE" TEXT,
# 	"RECORD_ID" BIGINT,
# 	"Loan_Range" TEXT,
# 	"BUSINESS_NAME_ORG" TEXT,
# 	"BUSINESS_ADDR_LINE1" TEXT,
# 	"BUSINESS_ADDR_CITY" TEXT,
# 	"BUSINESS_ADDR_STATE" TEXT,
# 	"BUSINESS_ADDR_POSTAL_CODE" TEXT,
# 	"NAICS_Code" TEXT,
# 	"Business_Type" TEXT,
# 	"OwnedByRaceEthnicity" TEXT,
# 	"OwnedBy" TEXT,
# 	"OwnedByVeteran" TEXT,
# 	"NonProfit" TEXT,
# 	"JobsReported" TEXT,
# 	"DateApproved" TEXT,
# 	"Lender" TEXT,
# 	"CD" TEXT
# )
#
# /*
# 3 rows from ppp table:
# RECORD_TYPE	DATA_SOURCE	RECORD_ID	Loan_Range	BUSINESS_NAME_ORG	BUSINESS_ADDR_LINE1	BUSINESS_ADDR_CITY	BUSINESS_ADDR_STATE	BUSINESS_ADDR_POSTAL_CODE	NAICS_Code	Business_Type	OwnedByRaceEthnicity	OwnedBy	OwnedByVeteran	NonProfit	JobsReported	DateApproved	Lender	CD
# ORGANIZATION	PPP_LOANS	7017	c $1-2 million	INFINITY HOSPICE CARE OF LAS VEGAS, LLC	5110 N 40TH ST STE 107	PHOENIX	AZ	85018	623110	Limited  Liability Company(LLC)	Unanswered	Male Owned	Unanswered		137	05/01/2020	JPMorgan Chase Bank, National Association	AZ-09
# ORGANIZATION	PPP_LOANS	7018	d $350,000-1 million	CLUB TATTOO LAS VEGAS LLC	1839 s. almaschool rd. ste 230	MESA	AZ	85210	812199	Limited  Liability Company(LLC)	Unanswered	Male Owned	Non-Veteran		15	05/01/2020	JPMorgan Chase Bank, National Association	AZ-09
# ORGANIZATION	PPP_LOANS	7021	d $350,000-1 million	LAS VEGAS LABOR, LLC	10265 W Camelback Rd, Ste 104	PHOENIX	AZ	85037	111421	Limited  Liability Company(LLC)	Unanswered	Unanswered	Unanswered		0	04/07/2020	UMB Bank, National Association	AZ-03
# */
# Invoking: `sql_db_schema` with `{'table_names': 'sg'}`
#
#
#
# CREATE TABLE sg (
# 	"DATA_SOURCE" TEXT,
# 	"RECORD_ID" TEXT,
# 	"RECORD_TYPE" TEXT,
# 	"PLACEKEY" TEXT,
# 	"REL_ANCHOR_DOMAIN" TEXT,
# 	"REL_ANCHOR_KEY" TEXT,
# 	"LOCATION_NAME_ORG" TEXT,
# 	"BRANDS" TEXT,
# 	"TOP_CATEGORY" TEXT,
# 	"SUB_CATEGORY" TEXT,
# 	"NAICS_CODE" TEXT,
# 	"BUSINESS_GEO_LATITUDE" TEXT,
# 	"BUSINESS_GEO_LONGITUDE" TEXT,
# 	"CATEGORY_TAGS" TEXT,
# 	"CLOSED_ON" TEXT,
# 	"TRACKING_CLOSED_SINCE" TEXT,
# 	"PHONE_NUMBER" TEXT,
# 	"BUSINESS_ADDR_COUNTRY" TEXT,
# 	"BUSINESS_ADDR_FULL" TEXT,
# 	"MAILING_VERIFIED_STATUS" TEXT,
# 	"REL_POINTER_DOMAIN" TEXT,
# 	"REL_POINTER_KEY" TEXT,
# 	"REL_POINTER_ROLE" TEXT,
# 	"OPENED_ON" TEXT,
# 	"IS_INTERSECTION" TEXT
# )
#
# /*
# 3 rows from sg table:
# DATA_SOURCE	RECORD_ID	RECORD_TYPE	PLACEKEY	REL_ANCHOR_DOMAIN	REL_ANCHOR_KEY	LOCATION_NAME_ORG	BRANDS	TOP_CATEGORY	SUB_CATEGORY	NAICS_CODE	BUSINESS_GEO_LATITUDE	BUSINESS_GEO_LONGITUDE	CATEGORY_TAGS	CLOSED_ON	TRACKING_CLOSED_SINCE	PHONE_NUMBER	BUSINESS_ADDR_COUNTRY	BUSINESS_ADDR_FULL	MAILING_VERIFIED_STATUS	REL_POINTER_DOMAIN	REL_POINTER_KEY	REL_POINTER_ROLE	OPENED_ON	IS_INTERSECTION
# SAFEGRAPH	225-222@5yv-j92-tn5	ORGANIZATION	225-222@5yv-j92-tn5	PLACEKEY	225-222@5yv-j92-tn5	Cantwell Michelle L Atty	[]	Legal Services	Offices of Lawyers	541110	36.145647	-115.186399	[]	2024-02-01	2019-07-01	+17023627800	US	3320 W Sahara Ave Las Vegas NV 89102-3223	VERIFIED_PREMISE	None	None	None	None	None
# SAFEGRAPH	226-222@5yv-hmm-whq	ORGANIZATION	226-222@5yv-hmm-whq	PLACEKEY	226-222@5yv-hmm-whq	Pieology Pizzeria	[ { "safegraph_brand_id": "SG_BRAND_f372f9969f6e1ae119a13ff4fc78fd2d", "safegraph_brand_name": "Pieo	Restaurants and Other Eating Places	Limited-Service Restaurants	722513	36.144906	-115.332644	[ "Counter Service", "Dinner", "Fast Food", "Lunch", "Pizza" ]	None	2019-07-01	+17023314454	US	10965 Lavender Hill Dr Ste 130 Las Vegas NV 89135-2951	VERIFIED_DELIVERY_POINT	PLACEKEY	zzw-223@5yv-hkm-rc5	PARENT	None	None
# SAFEGRAPH	22s-222@5yv-jbz-jgk	ORGANIZATION	22s-222@5yv-jbz-jgk	PLACEKEY	22s-222@5yv-jbz-jgk	Ellen Peneyra	[]	Offices of Other Health Practitioners	Offices of All Other Miscellaneous Health Practitioners	621399	36.10289	-115.121807	[]	None	2019-07-01	+17027397716	US	2275 Renaissance Dr Ste D Las Vegas NV 89119-6797	VERIFIED_DELIVERY_POINT	PLACEKEY	22g-222@5yv-jbz-h89	PARENT	None	None
# */
# Invoking: `sql_db_query_checker` with `{'query': 'SELECT ppp.BUSINESS_NAME_ORG, ppp.Loan_Range, dol.case_violtn_cnt \nFROM ppp \nJOIN dol ON ppp.BUSINESS_NAME_ORG = dol.BUSINESS_NAME_ORG \nORDER BY ppp.Loan_Range DESC, dol.case_violtn_cnt DESC \nLIMIT 10;'}`
# responded: To determine which companies that took on the biggest loans had the most violations, I need to join the `ppp` table (which contains loan information) with the `dol` table (which contains violation information). I will then sort the results by the loan amount and the number of violations.
#
# Let's start by identifying the companies with the largest loans and then check their violation counts.
#
# ```sql
# SELECT ppp.BUSINESS_NAME_ORG, ppp.Loan_Range, dol.case_violtn_cnt
# FROM ppp
# JOIN dol ON ppp.BUSINESS_NAME_ORG = dol.BUSINESS_NAME_ORG
# ORDER BY ppp.Loan_Range DESC, dol.case_violtn_cnt DESC
# LIMIT 10;
# ```
# Invoking: `sql_db_query` with `{'query': 'SELECT ppp.BUSINESS_NAME_ORG, ppp.Loan_Range, dol.case_violtn_cnt \nFROM ppp \nJOIN dol ON ppp.BUSINESS_NAME_ORG = dol.BUSINESS_NAME_ORG \nORDER BY ppp.Loan_Range DESC, dol.case_violtn_cnt DESC \nLIMIT 10;'}`
#
#
# [('HSG, LLC', 'd $350,000-1 million', 36)]The company that took on one of the biggest loans and had the most violations is HSG, LLC, with a loan range of $350,000-1 million and 36 violations.
#
# > Finished chain.
# {'input': 'of the companies that took on the biggest loans, which had the most violations?',
#  'output': 'The company that took on one of the biggest loans and had the most violations is HSG, LLC, with a loan range of $350,000-1 million and 36 violations.'}

# %% [markdown]
# ### Interesting.  Who are these folks?

# %%
sql_agent_executor.invoke('find all references to HSG, LLC')
# Out:
# > Entering new SQL Agent Executor chain...
#
# Invoking: `sql_db_list_tables` with `{}`
#
#
# dol, ppp, sg
# Invoking: `sql_db_schema` with `{'table_names': 'dol'}`
#
#
#
# CREATE TABLE dol (
# 	"RECORD_TYPE" TEXT,
# 	"DATA_SOURCE" TEXT,
# 	"RECORD_ID" BIGINT,
# 	case_id BIGINT,
# 	"BUSINESS_NAME_ORG" TEXT,
# 	"LEGAL_NAME_ORG" TEXT,
# 	"BUSINESS_ADDR_LINE1" TEXT,
# 	"BUSINESS_ADDR_CITY" TEXT,
# 	"BUSINESS_ADDR_STATE" TEXT,
# 	"BUSINESS_ADDR_POSTAL_CODE" TEXT,
# 	naic_cd TEXT,
# 	naics_code_description TEXT,
# 	case_violtn_cnt BIGINT
# )
#
# /*
# 3 rows from dol table:
# RECORD_TYPE	DATA_SOURCE	RECORD_ID	case_id	BUSINESS_NAME_ORG	LEGAL_NAME_ORG	BUSINESS_ADDR_LINE1	BUSINESS_ADDR_CITY	BUSINESS_ADDR_STATE	BUSINESS_ADDR_POSTAL_CODE	naic_cd	naics_code_description	case_violtn_cnt
# ORGANIZATION	DoL_WHISARD	53	1658108	Fabulous Freddy's (Trailwood)	Fabulous LLC	9611 Trail Wood Drive	Las Vegas	NV	89134	811192	Car Washes	0
# ORGANIZATION	DoL_WHISARD	165	1419689	Boulder Station Hotel & Casino	Boulder Station, Inc.	4111 Boulder Hwy	Las Vegas	NV	89121	721120	Casino Hotels	1
# ORGANIZATION	DoL_WHISARD	178	1424856	MSI Landscaping	MIST Systems International, Inc.	4820 Quality Court, #B	Las Vegas	NV	89103	561730	Landscaping Services	14
# */
# Invoking: `sql_db_schema` with `{'table_names': 'ppp'}`
#
#
#
# CREATE TABLE ppp (
# 	"RECORD_TYPE" TEXT,
# 	"DATA_SOURCE" TEXT,
# 	"RECORD_ID" BIGINT,
# 	"Loan_Range" TEXT,
# 	"BUSINESS_NAME_ORG" TEXT,
# 	"BUSINESS_ADDR_LINE1" TEXT,
# 	"BUSINESS_ADDR_CITY" TEXT,
# 	"BUSINESS_ADDR_STATE" TEXT,
# 	"BUSINESS_ADDR_POSTAL_CODE" TEXT,
# 	"NAICS_Code" TEXT,
# 	"Business_Type" TEXT,
# 	"OwnedByRaceEthnicity" TEXT,
# 	"OwnedBy" TEXT,
# 	"OwnedByVeteran" TEXT,
# 	"NonProfit" TEXT,
# 	"JobsReported" TEXT,
# 	"DateApproved" TEXT,
# 	"Lender" TEXT,
# 	"CD" TEXT
# )
#
# /*
# 3 rows from ppp table:
# RECORD_TYPE	DATA_SOURCE	RECORD_ID	Loan_Range	BUSINESS_NAME_ORG	BUSINESS_ADDR_LINE1	BUSINESS_ADDR_CITY	BUSINESS_ADDR_STATE	BUSINESS_ADDR_POSTAL_CODE	NAICS_Code	Business_Type	OwnedByRaceEthnicity	OwnedBy	OwnedByVeteran	NonProfit	JobsReported	DateApproved	Lender	CD
# ORGANIZATION	PPP_LOANS	7017	c $1-2 million	INFINITY HOSPICE CARE OF LAS VEGAS, LLC	5110 N 40TH ST STE 107	PHOENIX	AZ	85018	623110	Limited  Liability Company(LLC)	Unanswered	Male Owned	Unanswered		137	05/01/2020	JPMorgan Chase Bank, National Association	AZ-09
# ORGANIZATION	PPP_LOANS	7018	d $350,000-1 million	CLUB TATTOO LAS VEGAS LLC	1839 s. almaschool rd. ste 230	MESA	AZ	85210	812199	Limited  Liability Company(LLC)	Unanswered	Male Owned	Non-Veteran		15	05/01/2020	JPMorgan Chase Bank, National Association	AZ-09
# ORGANIZATION	PPP_LOANS	7021	d $350,000-1 million	LAS VEGAS LABOR, LLC	10265 W Camelback Rd, Ste 104	PHOENIX	AZ	85037	111421	Limited  Liability Company(LLC)	Unanswered	Unanswered	Unanswered		0	04/07/2020	UMB Bank, National Association	AZ-03
# */
# Invoking: `sql_db_schema` with `{'table_names': 'sg'}`
#
#
#
# CREATE TABLE sg (
# 	"DATA_SOURCE" TEXT,
# 	"RECORD_ID" TEXT,
# 	"RECORD_TYPE" TEXT,
# 	"PLACEKEY" TEXT,
# 	"REL_ANCHOR_DOMAIN" TEXT,
# 	"REL_ANCHOR_KEY" TEXT,
# 	"LOCATION_NAME_ORG" TEXT,
# 	"BRANDS" TEXT,
# 	"TOP_CATEGORY" TEXT,
# 	"SUB_CATEGORY" TEXT,
# 	"NAICS_CODE" TEXT,
# 	"BUSINESS_GEO_LATITUDE" TEXT,
# 	"BUSINESS_GEO_LONGITUDE" TEXT,
# 	"CATEGORY_TAGS" TEXT,
# 	"CLOSED_ON" TEXT,
# 	"TRACKING_CLOSED_SINCE" TEXT,
# 	"PHONE_NUMBER" TEXT,
# 	"BUSINESS_ADDR_COUNTRY" TEXT,
# 	"BUSINESS_ADDR_FULL" TEXT,
# 	"MAILING_VERIFIED_STATUS" TEXT,
# 	"REL_POINTER_DOMAIN" TEXT,
# 	"REL_POINTER_KEY" TEXT,
# 	"REL_POINTER_ROLE" TEXT,
# 	"OPENED_ON" TEXT,
# 	"IS_INTERSECTION" TEXT
# )
#
# /*
# 3 rows from sg table:
# DATA_SOURCE	RECORD_ID	RECORD_TYPE	PLACEKEY	REL_ANCHOR_DOMAIN	REL_ANCHOR_KEY	LOCATION_NAME_ORG	BRANDS	TOP_CATEGORY	SUB_CATEGORY	NAICS_CODE	BUSINESS_GEO_LATITUDE	BUSINESS_GEO_LONGITUDE	CATEGORY_TAGS	CLOSED_ON	TRACKING_CLOSED_SINCE	PHONE_NUMBER	BUSINESS_ADDR_COUNTRY	BUSINESS_ADDR_FULL	MAILING_VERIFIED_STATUS	REL_POINTER_DOMAIN	REL_POINTER_KEY	REL_POINTER_ROLE	OPENED_ON	IS_INTERSECTION
# SAFEGRAPH	225-222@5yv-j92-tn5	ORGANIZATION	225-222@5yv-j92-tn5	PLACEKEY	225-222@5yv-j92-tn5	Cantwell Michelle L Atty	[]	Legal Services	Offices of Lawyers	541110	36.145647	-115.186399	[]	2024-02-01	2019-07-01	+17023627800	US	3320 W Sahara Ave Las Vegas NV 89102-3223	VERIFIED_PREMISE	None	None	None	None	None
# SAFEGRAPH	226-222@5yv-hmm-whq	ORGANIZATION	226-222@5yv-hmm-whq	PLACEKEY	226-222@5yv-hmm-whq	Pieology Pizzeria	[ { "safegraph_brand_id": "SG_BRAND_f372f9969f6e1ae119a13ff4fc78fd2d", "safegraph_brand_name": "Pieo	Restaurants and Other Eating Places	Limited-Service Restaurants	722513	36.144906	-115.332644	[ "Counter Service", "Dinner", "Fast Food", "Lunch", "Pizza" ]	None	2019-07-01	+17023314454	US	10965 Lavender Hill Dr Ste 130 Las Vegas NV 89135-2951	VERIFIED_DELIVERY_POINT	PLACEKEY	zzw-223@5yv-hkm-rc5	PARENT	None	None
# SAFEGRAPH	22s-222@5yv-jbz-jgk	ORGANIZATION	22s-222@5yv-jbz-jgk	PLACEKEY	22s-222@5yv-jbz-jgk	Ellen Peneyra	[]	Offices of Other Health Practitioners	Offices of All Other Miscellaneous Health Practitioners	621399	36.10289	-115.121807	[]	None	2019-07-01	+17027397716	US	2275 Renaissance Dr Ste D Las Vegas NV 89119-6797	VERIFIED_DELIVERY_POINT	PLACEKEY	22g-222@5yv-jbz-h89	PARENT	None	None
# */
# Invoking: `sql_db_query_checker` with `{'query': "SELECT BUSINESS_NAME_ORG, LEGAL_NAME_ORG, BUSINESS_ADDR_LINE1, BUSINESS_ADDR_CITY, BUSINESS_ADDR_STATE, BUSINESS_ADDR_POSTAL_CODE FROM dol WHERE BUSINESS_NAME_ORG LIKE '%HSG, LLC%' OR LEGAL_NAME_ORG LIKE '%HSG, LLC%' LIMIT 10;"}`
#
#
# ```sql
# SELECT BUSINESS_NAME_ORG, LEGAL_NAME_ORG, BUSINESS_ADDR_LINE1, BUSINESS_ADDR_CITY, BUSINESS_ADDR_STATE, BUSINESS_ADDR_POSTAL_CODE
# FROM dol
# WHERE BUSINESS_NAME_ORG LIKE '%HSG, LLC%' OR LEGAL_NAME_ORG LIKE '%HSG, LLC%'
# LIMIT 10;
# ```
# Invoking: `sql_db_query_checker` with `{'query': "SELECT BUSINESS_NAME_ORG, BUSINESS_ADDR_LINE1, BUSINESS_ADDR_CITY, BUSINESS_ADDR_STATE, BUSINESS_ADDR_POSTAL_CODE FROM ppp WHERE BUSINESS_NAME_ORG LIKE '%HSG, LLC%' LIMIT 10;"}`
#
#
# ```sql
# SELECT BUSINESS_NAME_ORG, BUSINESS_ADDR_LINE1, BUSINESS_ADDR_CITY, BUSINESS_ADDR_STATE, BUSINESS_ADDR_POSTAL_CODE
# FROM ppp
# WHERE BUSINESS_NAME_ORG LIKE '%HSG, LLC%'
# LIMIT 10;
# ```
# Invoking: `sql_db_query_checker` with `{'query': "SELECT LOCATION_NAME_ORG, BUSINESS_ADDR_FULL FROM sg WHERE LOCATION_NAME_ORG LIKE '%HSG, LLC%' LIMIT 10;"}`
#
#
# ```sql
# SELECT LOCATION_NAME_ORG, BUSINESS_ADDR_FULL
# FROM sg
# WHERE LOCATION_NAME_ORG LIKE '%HSG, LLC%'
# LIMIT 10;
# ```
# Invoking: `sql_db_query` with `{'query': "SELECT BUSINESS_NAME_ORG, LEGAL_NAME_ORG, BUSINESS_ADDR_LINE1, BUSINESS_ADDR_CITY, BUSINESS_ADDR_STATE, BUSINESS_ADDR_POSTAL_CODE FROM dol WHERE BUSINESS_NAME_ORG LIKE '%HSG, LLC%' OR LEGAL_NAME_ORG LIKE '%HSG, LLC%' LIMIT 10;"}`
#
#
# [('HSG, LLC', 'HSG, LLC', '4001 South Decatur Blvd', 'Las Vegas', 'NV', '89103')]
# Invoking: `sql_db_query` with `{'query': "SELECT BUSINESS_NAME_ORG, BUSINESS_ADDR_LINE1, BUSINESS_ADDR_CITY, BUSINESS_ADDR_STATE, BUSINESS_ADDR_POSTAL_CODE FROM ppp WHERE BUSINESS_NAME_ORG LIKE '%HSG, LLC%' LIMIT 10;"}`
#
#
# [('HSG, LLC', '4001 S. Decatur Blvd. #37-376', 'LAS VEGAS', 'NV', '89103')]
# Invoking: `sql_db_query` with `{'query': "SELECT LOCATION_NAME_ORG, BUSINESS_ADDR_FULL FROM sg WHERE LOCATION_NAME_ORG LIKE '%HSG, LLC%' LIMIT 10;"}`
#
#
# Here are the references to "HSG, LLC" found in the database:
#
# From the `dol` table:
# - **Business Name:** HSG, LLC
#   - **Legal Name:** HSG, LLC
#   - **Address:** 4001 South Decatur Blvd, Las Vegas, NV, 89103
#
# From the `ppp` table:
# - **Business Name:** HSG, LLC
#   - **Address:** 4001 S. Decatur Blvd. #37-376, Las Vegas, NV, 89103
#
# No references to "HSG, LLC" were found in the `sg` table.
#
# > Finished chain.
# {'input': 'find all references to HSG, LLC',
#  'output': 'Here are the references to "HSG, LLC" found in the database:\n\nFrom the `dol` table:\n- **Business Name:** HSG, LLC\n  - **Legal Name:** HSG, LLC\n  - **Address:** 4001 South Decatur Blvd, Las Vegas, NV, 89103\n\nFrom the `ppp` table:\n- **Business Name:** HSG, LLC\n  - **Address:** 4001 S. Decatur Blvd. #37-376, Las Vegas, NV, 89103\n\nNo references to "HSG, LLC" were found in the `sg` table.'}

# %% [markdown]
# ### Some details about this
#
# So I looked and it turns out that 4001 South Decatur Blvd is a strip mall.  And it just so happens that Suite 37 is a UPS Store, which means that this is probably a company with a PO box in that store.  In fact, if you search you will find that there are several businesses in this data set with the same address.  However, interesting things happen if you look at this entry within `G2Explorer.py`.  (See the blog post for that!)
